# %%
import os
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline

# %%
df = pd.read_csv("./Li-ion_Batteries/HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_a_cycle_data.csv")
# To display the top 5 rows 
df.shape
# Out:
# (1101, 12)

# %%
df.dtypes
# Out:
# Cycle_Index                float64
# Start_Time                 float64
# End_Time                   float64
# Test_Time (s)              float64
# Min_Current (A)            float64
# Max_Current (A)            float64
# Min_Voltage (V)            float64
# Max_Voltage (V)            float64
# Charge_Capacity (Ah)       float64
# Discharge_Capacity (Ah)    float64
# Charge_Energy (Wh)         float64
# Discharge_Energy (Wh)      float64
# dtype: object

# %%
diff = df['Test_Time (s)'].diff()
df = df[diff != 0]
df.shape
# Out:
# (1085, 12)

# %%
df.tail(5)
# Out:
#       Cycle_Index  Start_Time  End_Time  Test_Time (s)  Min_Current (A)  \
# 1096       1109.0         NaN       NaN   1.552904e+07           -4.199
# 1097       1110.0         NaN       NaN   1.553696e+07           -4.199
# 1098       1111.0         NaN       NaN   1.554489e+07           -4.199
# 1099       1112.0         NaN       NaN   1.559678e+07           -4.199
# 1100       1113.0         NaN       NaN   1.627624e+07           -2.802
#
#       Max_Current (A)  Min_Voltage (V)  Max_Voltage (V)  Charge_Capacity (Ah)  \
# 1096            1.349            2.999            4.301                 1.077
# 1097            1.349            2.999            4.305                 1.077
# 1098            1.349            2.999            4.301                 1.074
# 1099            1.349            2.999            4.303                 1.055
# 1100            2.802            2.999            4.300                 2.046
#
#       Discharge_Capacity (Ah)  Charge_Energy (Wh)  Discharge_Energy (Wh)
# 1096                    1.089               4.484                  3.635
# 1097                    1.086               4.483                  3.624
# 1098                    1.080               4.472                  3.603
# 1099                    1.059               4.444                  3.513
# 1100                    2.165               8.393                  8.185

# %%
df['Cycle_Index'].iloc[-1]
# Out:
# 1113.0

# %%
np.convolve(df['Charge_Capacity (Ah)'].iloc[14:25], np.ones(11)/11, mode='valid')[0]
# Out:
# 2.4849090909090914

# %%
row = 20
np.convolve(df['Charge_Capacity (Ah)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')
# Out:
# array([2.5039])

# %%
cur_cycle_time = df['Test_Time (s)'].iloc[row] - df['Test_Time (s)'].iloc[row - 1]
print(cur_cycle_time)
# Out:
# 11501.214000000153

# %%
str = 'CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a_cycle_data.csv'

# %%
str.replace('_cycle_data.csv', '')
# Out:
# 'CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a'

# %%
def add_to_df(df_to_add_to: pd.DataFrame, df_to_add_from: pd.DataFrame, file_name):
    df = df_to_add_from
    diff = df['Test_Time (s)'].diff()
    df = df[diff > 0]
    
    cycle_l = []
    cycle_time_l = []
    min_current_l = []
    max_current_l = []
    min_voltage_l = []
    max_voltage_l = []
    discharge_capacity_l = []
    charge_energy_l = []
    discharge_energy_l = []
    charge_capacity_l = []
    discharge_capacity_l = []
    charge_energy_l = []
    discharge_energy_l = []
    efficiency_l = []

    charge_capacity_change_l = []
    discharge_capacity_change_l = []
    charge_energy_change_l = []
    discharge_energy_change_l = []
    # 0th
    fab_charge_capacity = df['Charge_Capacity (Ah)'].iloc[0]
    fab_discharge_capacity = df['Discharge_Capacity (Ah)'].iloc[0]
    fab_charge_energy = df['Charge_Energy (Wh)'].iloc[0]
    fab_discharge_energy = df['Discharge_Energy (Wh)'].iloc[0]

    cycle_l.append(0)
    cycle_time_l.append(df['Test_Time (s)'].iloc[0])

    min_current_l.append(df['Min_Current (A)'].iloc[0])
    max_current_l.append(df['Max_Current (A)'].iloc[0])
    
    min_voltage_l.append(df['Min_Voltage (V)'].iloc[0])
    max_voltage_l.append(df['Max_Voltage (V)'].iloc[0])

    charge_capacity_l.append(fab_charge_capacity)
    discharge_capacity_l.append(fab_discharge_capacity)
    charge_energy_l.append(fab_charge_energy)
    discharge_energy_l.append(fab_discharge_energy)

    charge_capacity_change_l.append(1/fab_charge_capacity)
    discharge_capacity_change_l.append(1/fab_discharge_capacity)
    charge_energy_change_l.append(1/fab_charge_energy)
    discharge_energy_change_l.append(1/fab_discharge_energy)
    efficiency_l.append(1 / fab_charge_energy)
    # 1st
    init_charge_capacity = df['Charge_Capacity (Ah)'].iloc[1]
    init_discharge_capacity = df['Discharge_Capacity (Ah)'].iloc[1]
    init_charge_energy = df['Charge_Energy (Wh)'].iloc[1]
    init_discharge_energy = df['Discharge_Energy (Wh)'].iloc[1]

    cycle_l.append(1)
    cycle_time_l.append(df['Test_Time (s)'].iloc[1] - df['Test_Time (s)'].iloc[0])

    min_current_l.append(df['Min_Current (A)'].iloc[1])
    max_current_l.append(df['Max_Current (A)'].iloc[1])
    
    min_voltage_l.append(df['Min_Voltage (V)'].iloc[1])
    max_voltage_l.append(df['Max_Voltage (V)'].iloc[1])

    charge_capacity_l.append(init_charge_capacity)
    discharge_capacity_l.append(init_discharge_capacity)
    charge_energy_l.append(init_charge_energy)
    discharge_energy_l.append(init_discharge_energy)

    charge_capacity_change_l.append(1)
    discharge_capacity_change_l.append(1)
    charge_energy_change_l.append(1)
    discharge_energy_change_l.append(1)
    efficiency_l.append(1)
    
    stop = int(df.shape[0]) - 1
    for i, row in enumerate(range(21, stop, 20)):
        cur_cycle = row

        cur_cycle_time = df['Test_Time (s)'].iloc[row] - df['Test_Time (s)'].iloc[row - 1]

        cur_min_current = np.convolve(df['Min_Current (A)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_max_current = np.convolve(df['Max_Current (A)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        
        cur_min_voltage = np.convolve(df['Min_Voltage (V)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_max_voltage = np.convolve(df['Max_Voltage (V)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]

        cur_charge_capacity = np.convolve(df['Charge_Capacity (Ah)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_charge_capacity_change = cur_charge_capacity/init_charge_capacity

        cur_discharge_capacity = np.convolve(df['Discharge_Capacity (Ah)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_discharge_capacity_change = cur_discharge_capacity/init_discharge_capacity

        cur_charge_energy = np.convolve(df['Charge_Energy (Wh)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_charge_energy_change = cur_charge_energy/init_charge_energy

        cur_discharge_energy = np.convolve(df['Discharge_Energy (Wh)'].iloc[row - 10:row + 10], np.ones(20)/20, mode='valid')[0]
        cur_discharge_energy_change = cur_discharge_energy/init_discharge_energy

        cur_efficiency = cur_discharge_energy / cur_charge_energy

        cycle_l.append(cur_cycle)
        cycle_time_l.append(cur_cycle_time)

        min_current_l.append(cur_min_current)
        max_current_l.append(cur_max_current)
        min_voltage_l.append(cur_min_voltage)
        max_voltage_l.append(cur_max_voltage)

        charge_capacity_l.append(cur_charge_capacity)
        discharge_capacity_l.append(cur_discharge_capacity)
        charge_energy_l.append(cur_charge_energy)
        discharge_energy_l.append(cur_discharge_energy)
        efficiency_l.append(cur_efficiency)

        charge_capacity_change_l.append(cur_charge_capacity_change)
        discharge_capacity_change_l.append(cur_discharge_capacity_change)
        charge_energy_change_l.append(cur_charge_energy_change)
        discharge_energy_change_l.append(cur_discharge_energy_change)

    local_df = pd.DataFrame()

    local_df["Cell ID"] = np.array([file_name] * len(cycle_l))
    local_df["Cycle"] = np.array(cycle_l)
    local_df["Cycle_time"] = np.array(cycle_time_l)

    local_df["Min_current"] = np.array(min_current_l)
    local_df["Max_current"] = np.array(max_current_l)
    local_df["Min_voltage"] = np.array(min_voltage_l)
    local_df["Max_voltage"] = np.array(max_voltage_l)

    local_df["Charge_capacity"] = np.array(charge_capacity_l)
    local_df["Charge_capacity_ratio"] = np.array(charge_capacity_change_l)
    local_df["Discharge_capacity"] = np.array(discharge_capacity_l)
    local_df["Discharge_capacity_ratio"] = np.array(discharge_capacity_change_l)

    local_df["Charge_energy"] = np.array(charge_energy_l)
    local_df["Charge_energy_ratio"] = np.array(charge_energy_change_l)
    local_df["Discharge_energy"] = np.array(discharge_energy_l)
    local_df["Discharge_energy_ratio"] = np.array(discharge_energy_change_l)
    local_df["Efficiency"] = np.array(efficiency_l)


    df_to_add_to = pd.concat([df_to_add_to, local_df])
    return df_to_add_to

# %%
def process_csvs():
    csvs_l = os.listdir('./Li-ion_Batteries/')
    general_dataframe = pd.DataFrame(columns=['Cell ID', 'Cycle', 'Cycle_time', 
                                'Min_current', 'Max_current',
                                'Min_voltage', 'Max_voltage',
                                'Charge_capacity', 'Charge_capacity_ratio',
                                'Discharge_capacity', 'Discharge_capacity_ratio',
                                'Charge_energy', 'Charge_energy_ratio',
                                'Discharge_energy', 'Discharge_energy_ratio',
                                'Efficiency'])
    for csv_name in csvs_l:
        print(csv_name)
        df_to_add_from = pd.read_csv("./Li-ion_Batteries/" + csv_name)
        general_dataframe = add_to_df(general_dataframe, df_to_add_from, csv_name.replace('_cycle_data.csv', ''))
    general_dataframe = general_dataframe.reset_index()
    general_dataframe = general_dataframe.rename(columns={"index": "Internal_index"})

    d = {'Cell ID': 'object', 'Cycle': 'int64', 'Cycle_time': 'float64', 
            'Min_current': 'float64', 'Max_current': 'float64',
            'Min_voltage': 'float64', 'Max_voltage': 'float64',
            'Charge_capacity': 'float64', 'Charge_capacity_ratio': 'float64',
            'Discharge_capacity': 'float64', 'Discharge_capacity_ratio': 'float64',
            'Charge_energy': 'float64', 'Charge_energy_ratio': 'float64',
            'Discharge_energy': 'float64', 'Discharge_energy_ratio': 'float64',
            'Efficiency': 'float64'}
    general_dataframe =general_dataframe.astype(d)

    return general_dataframe

# %%
general_dataframe = process_csvs()
general_dataframe.head(5)
# Out:
# CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a_cycle_data.csv
# CALCE_CX2-25_prism_LCO_25C_0-100_0.5-0.5C_b_cycle_data.csv
# CALCE_CX2-33_prism_LCO_25C_0-100_0.5-0.5C_d_cycle_data.csv
# CALCE_CX2-34_prism_LCO_25C_0-100_0.5-0.5C_e_cycle_data.csv
# CALCE_CX2-36_prism_LCO_25C_0-100_0.5-0.5C_f_cycle_data.csv
# CALCE_CX2-37_prism_LCO_25C_0-100_0.5-0.5C_g_cycle_data.csv
# CALCE_CX2-38_prism_LCO_25C_0-100_0.5-0.5C_h_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_a_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_b_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_c_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_d_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_e_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_f_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_g_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_j_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_l_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_m_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_n_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_o_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_p_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_s_cycle_data.csv
# HNEI_18650_NMC_LCO_25C_0-100_0.5-1.5C_t_cycle_data.csv
# OX_1-1_pouch_LCO_40C_0-100_2-1.84C_a_cycle_data.csv
# OX_1-2_pouch_LCO_40C_0-100_2-1.84C_b_cycle_data.csv
# OX_1-3_pouch_LCO_40C_0-100_2-1.84C_c_cycle_data.csv
# OX_1-4_pouch_LCO_40C_0-100_2-1.84C_d_cycle_data.csv
# OX_1-5_pouch_LCO_40C_0-100_2-1.84C_e_cycle_data.csv
# OX_1-6_pouch_LCO_40C_0-100_2-1.84C_f_cycle_data.csv
# OX_1-7_pouch_LCO_40C_0-100_2-1.84C_g_cycle_data.csv
# OX_1-8_pouch_LCO_40C_0-100_2-1.84C_h_cycle_data.csv
# SNL_18650_LFP_15C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_LFP_15C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_LFP_15C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_LFP_15C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-0.5C_a_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-3C_a_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-3C_b_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-3C_c_cycle_data.csv
# SNL_18650_LFP_25C_0-100_0.5-3C_d_cycle_data.csv
# SNL_18650_LFP_25C_20-80_0.5-0.5C_a_cycle_data.csv
# SNL_18650_LFP_25C_20-80_0.5-0.5C_b_cycle_data.csv
# SNL_18650_LFP_25C_20-80_0.5-0.5C_c_cycle_data.csv
# SNL_18650_LFP_25C_20-80_0.5-0.5C_d_cycle_data.csv
# SNL_18650_LFP_25C_20-80_0.5-3C_a_cycle_data.csv
# SNL_18650_LFP_25C_40-60_0.5-0.5C_a_cycle_data.csv
# SNL_18650_LFP_25C_40-60_0.5-0.5C_b_cycle_data.csv
# SNL_18650_LFP_25C_40-60_0.5-3C_a_cycle_data.csv
# SNL_18650_LFP_25C_40-60_0.5-3C_b_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_LFP_35C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NCA_15C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NCA_15C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NCA_15C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NCA_15C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NCA_25C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NCA_25C_20-80_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NCA_25C_20-80_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NCA_25C_20-80_0.5-0.5C_c_cycle_data.csv
# SNL_18650_NCA_25C_20-80_0.5-0.5C_d_cycle_data.csv
# SNL_18650_NCA_25C_40-60_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NCA_25C_40-60_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NCA_35C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NMC_15C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NMC_15C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NMC_15C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NMC_15C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-2C_b_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-3C_a_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-3C_b_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-3C_c_cycle_data.csv
# SNL_18650_NMC_25C_0-100_0.5-3C_d_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-0.5C_c_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-0.5C_d_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-3C_a_cycle_data.csv
# SNL_18650_NMC_25C_20-80_0.5-3C_b_cycle_data.csv
# SNL_18650_NMC_25C_40-60_0.5-0.5C_a_cycle_data.csv
# SNL_18650_NMC_25C_40-60_0.5-0.5C_b_cycle_data.csv
# SNL_18650_NMC_25C_40-60_0.5-3C_a_cycle_data.csv
# SNL_18650_NMC_25C_40-60_0.5-3C_b_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-1C_a_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-1C_b_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-1C_c_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-1C_d_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-2C_a_cycle_data.csv
# SNL_18650_NMC_35C_0-100_0.5-2C_b_cycle_data.csv
# UL-PUR_N10-EX9_18650_NCA_23C_0-100_0.5-0.5C_i_cycle_data.csv
# UL-PUR_N10-NA7_18650_NCA_23C_0-100_0.5-0.5C_g_cycle_data.csv
# UL-PUR_N10-OV8_18650_NCA_23C_0-100_0.5-0.5C_h_cycle_data.csv
# UL-PUR_N15-EX4_18650_NCA_23C_0-100_0.5-0.5C_d_cycle_data.csv
# UL-PUR_N15-NA10_18650_NCA_23C_0-100_0.5-0.5C_j_cycle_data.csv
# UL-PUR_N15-OV3_18650_NCA_23C_0-100_0.5-0.5C_c_cycle_data.csv
# UL-PUR_N20-EX2_18650_NCA_23C_0-100_0.5-0.5C_b_cycle_data.csv
# UL-PUR_N20-NA5_18650_NCA_23C_0-100_0.5-0.5C_e_cycle_data.csv
# UL-PUR_N20-NA6_18650_NCA_23C_0-100_0.5-0.5C_f_cycle_data.csv
# UL-PUR_N20-OV1_18650_NCA_23C_0-100_0.5-0.5C_a_cycle_data.csv
# UL-PUR_R10-EX6_18650_NCA_23C_2.5-96.5_0.5-0.5C_f_cycle_data.csv
# UL-PUR_R10-NA11_18650_NCA_23C_2.5-96.5_0.5-0.5C_k_cycle_data.csv
# UL-PUR_R10-OV5_18650_NCA_23C_2.5-96.5_0.5-0.5C_e_cycle_data.csv
# UL-PUR_R15-EX4_18650_NCA_23C_2.5-96.5_0.5-0.5C_d_cycle_data.csv
# UL-PUR_R15-NA10_18650_NCA_23C_2.5-96.5_0.5-0.5C_j_cycle_data.csv
# UL-PUR_R15-OV3_18650_NCA_23C_2.5-96.5_0.5-0.5C_c_cycle_data.csv
# UL-PUR_R20-EX2_18650_NCA_23C_2.5-96.5_0.5-0.5C_b_cycle_data.csv
# UL-PUR_R20-NA7_18650_NCA_23C_2.5-96.5_0.5-0.5C_g_cycle_data.csv
# UL-PUR_R20-NA8_18650_NCA_23C_2.5-96.5_0.5-0.5C_h_cycle_data.csv
# UL-PUR_R20-NA9_18650_NCA_23C_2.5-96.5_0.5-0.5C_i_cycle_data.csv
# UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a_cycle_data.csv
#    Internal_index                                      Cell ID  Cycle  \
# 0               0  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a      0
# 1               1  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a      1
# 2               2  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a     21
# 3               3  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a     41
# 4               4  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a     61
#
#    Cycle_time  Min_current  Max_current  Min_voltage  Max_voltage  \
# 0   28594.592     -0.55000      1.27500        2.699      4.20000
# 1   17680.531     -0.55100      1.29300        2.699      4.20000
# 2   17558.992     -0.55785      1.25565        2.699      4.20095
# 3   17511.676     -0.55000      1.29460        2.699      4.20180
# 4   17508.048     -0.55110      1.26530        2.699      4.20145
#
#    Charge_capacity  Charge_capacity_ratio  Discharge_capacity  \
# 0          1.26800               0.788644             1.26900
# 1          1.26800               1.000000             1.26900
# 2          1.25355               0.988604             1.25335
# 3          1.25905               0.992942             1.26040
# 4          1.25475               0.989550             1.25450
#
#    Discharge_capacity_ratio  Charge_energy  Charge_energy_ratio  \
# 0                  0.788022        5.07300             0.197122
# 1                  1.000000        5.07100             1.000000
# 2                  0.987667        5.01130             0.988227
# 3                  0.993223        5.03610             0.993118
# 4                  0.988574        5.01225             0.988415
#
#    Discharge_energy  Discharge_energy_ratio  Efficiency
# 0           4.72500                0.211640    0.197122
# 1           4.73000                1.000000    1.000000
# 2           4.66770                0.986829    0.931435
# 3           4.69795                0.993224    0.932855
# 4           4.67840                0.989091    0.933393

# %%
general_dataframe.tail(5)
# Out:
#        Internal_index                                           Cell ID  \
# 15921              36  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a
# 15922              37  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a
# 15923              38  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a
# 15924              39  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a
# 15925              40  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a
#
#        Cycle  Cycle_time  Min_current  Max_current  Min_voltage  Max_voltage  \
# 15921    701   15525.673        -1.60       1.6010      2.90000          4.0
# 15922    721   15269.862        -1.60       1.6010      2.90000          4.0
# 15923    741   15344.016        -1.60       1.6010      2.89985          4.0
# 15924    761   15226.890        -1.60       1.6010      2.89975          4.0
# 15925    781   15204.725        -1.28       1.2808      2.34605          3.2
#
#        Charge_capacity  Charge_capacity_ratio  Discharge_capacity  \
# 15921          1.98470               0.723287             1.97970
# 15922          2.03780               0.742638             2.03100
# 15923          2.06200               0.751458             2.05885
# 15924          2.03095               0.740142             2.02580
# 15925          1.63990               0.597631             1.55815
#
#        Discharge_capacity_ratio  Charge_energy  Charge_energy_ratio  \
# 15921                  0.721991        7.65255             0.739734
# 15922                  0.740700        7.87130             0.760880
# 15923                  0.750857        7.97105             0.770522
# 15924                  0.738804        7.84495             0.758333
# 15925                  0.568253        6.34175             0.613026
#
#        Discharge_energy  Discharge_energy_ratio  Efficiency
# 15921           6.78380                0.715742    0.886476
# 15922           6.96880                0.735261    0.885343
# 15923           7.07115                0.746059    0.887104
# 15924           6.95290                0.733583    0.886290
# 15925           5.35765                0.565272    0.844822

# %%
general_dataframe.shape
# Out:
# (15926, 17)

# %%
general_dataframe.dtypes
# Out:
# Internal_index                int64
# Cell ID                      object
# Cycle                         int64
# Cycle_time                  float64
# Min_current                 float64
# Max_current                 float64
# Min_voltage                 float64
# Max_voltage                 float64
# Charge_capacity             float64
# Charge_capacity_ratio       float64
# Discharge_capacity          float64
# Discharge_capacity_ratio    float64
# Charge_energy               float64
# Charge_energy_ratio         float64
# Discharge_energy            float64
# Discharge_energy_ratio      float64
# Efficiency                  float64
# dtype: object

# %%
general_dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15926 entries, 0 to 15925
# Data columns (total 17 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Internal_index            15926 non-null  int64
#  1   Cell ID                   15926 non-null  object
#  2   Cycle                     15926 non-null  int64
#  3   Cycle_time                15926 non-null  float64
#  4   Min_current               15926 non-null  float64
#  5   Max_current               15926 non-null  float64
#  6   Min_voltage               15926 non-null  float64
#  7   Max_voltage               15926 non-null  float64
#  8   Charge_capacity           15926 non-null  float64
#  9   Charge_capacity_ratio     15926 non-null  float64
#  10  Discharge_capacity        15926 non-null  float64
#  11  Discharge_capacity_ratio  15926 non-null  float64
#  12  Charge_energy             15926 non-null  float64
#  13  Charge_energy_ratio       15926 non-null  float64
#  14  Discharge_energy          15926 non-null  float64
#  15  Discharge_energy_ratio    15926 non-null  float64
#  16  Efficiency                15926 non-null  float64
# dtypes: float64(14), int64(2), object(1)
# memory usage: 2.1+ MB

# %%
general_dataframe.describe().T
# Out:
#                             count         mean           std        min  \
# Internal_index            15926.0   173.642785    193.509198   0.000000
# Cycle                     15926.0  3454.019151   3870.037679   0.000000
# Cycle_time                15926.0  9446.635034  39700.673438  59.989000
# Min_current               15926.0    -2.575453      2.443233  -9.003850
# Max_current               15926.0     0.981946      0.473353   0.092300
# Min_voltage               15926.0     2.734112      0.521899   1.230750
# Max_voltage               15926.0     3.727563      0.316158   1.996600
# Charge_capacity           15926.0     0.978284      0.736684   0.004750
# Charge_capacity_ratio     15926.0     0.542127      0.326173   0.004435
# Discharge_capacity        15926.0     0.978411      0.735627   0.008300
# Discharge_capacity_ratio  15926.0     0.542917      0.326169   0.007743
# Charge_energy             15926.0     3.623889      2.926469   0.016600
# Charge_energy_ratio       15926.0     0.538456      0.328612   0.004620
# Discharge_energy          15926.0     3.247572      2.543075   0.027100
# Discharge_energy_ratio    15926.0     0.520802      0.317917   0.007864
# Efficiency                15926.0     0.910873      0.095762   0.075239
#
#                                   25%          50%           75%           max
# Internal_index              33.000000   104.000000    242.000000  9.590000e+02
# Cycle                      641.000000  2061.000000   4821.000000  1.916100e+04
# Cycle_time                2327.910500  7763.576000  10025.573000  1.497806e+06
# Min_current                 -3.300000    -1.600000     -1.099000 -3.310000e-01
# Max_current                  0.549000     0.550000      1.499700  2.171800e+00
# Min_voltage                  1.997900     2.980925      3.159000  3.560450e+00
# Max_voltage                  3.390000     3.600000      4.000000  4.354000e+00
# Charge_capacity              0.551475     0.892275      1.167800  3.432000e+00
# Charge_capacity_ratio        0.205800     0.523936      0.881697  1.736263e+00
# Discharge_capacity           0.554238     0.892000      1.169537  3.355000e+00
# Discharge_capacity_ratio     0.206186     0.525041      0.883680  1.388889e+00
# Charge_energy                1.848263     3.036650      4.670300  1.329100e+01
# Charge_energy_ratio          0.199869     0.522703      0.882902  1.727738e+00
# Discharge_energy             1.770700     2.752075      4.122637  1.177400e+01
# Discharge_energy_ratio       0.196994     0.520842      0.852945  1.355095e+00
# Efficiency                   0.890458     0.921469      0.954446  4.393350e+00

# %%
general_dataframe.to_csv('li-ion_batteries_cycling_stats_aggregated.csv')
