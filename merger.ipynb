# %%
import pandas as pd
import numpy as np
import seaborn as sns                       #visualisation
import matplotlib.pyplot as plt             #visualisation
# %matplotlib inline
# Out:
# c:\Soft\Anaconda\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
df = pd.read_csv("li-ion_batteries.csv")
# To display the top 5 rows 
df.head(5)
# Out:
#                                        Cell ID     Anode Cathode Source    Ah  \
# 0  CALCE_CX2-16_prism_LCO_25C_0-100_0.5-0.5C_a  graphite     LCO  calce  1.35
# 1  CALCE_CX2-25_prism_LCO_25C_0-100_0.5-0.5C_b  graphite     LCO  calce  1.35
# 2  CALCE_CX2-33_prism_LCO_25C_0-100_0.5-0.5C_d  graphite     LCO  calce  1.35
# 3  CALCE_CX2-34_prism_LCO_25C_0-100_0.5-0.5C_e  graphite     LCO  calce  1.35
# 4  CALCE_CX2-36_prism_LCO_25C_0-100_0.5-0.5C_f  graphite     LCO  calce  1.35
#
#   Form Factor  Temperature (C)  Max SOC  Min SOC  Charge Rate (C)  \
# 0   prismatic               25    100.0      0.0              0.5
# 1   prismatic               25    100.0      0.0              0.5
# 2   prismatic               25    100.0      0.0              0.5
# 3   prismatic               25    100.0      0.0              0.5
# 4   prismatic               25    100.0      0.0              0.5
#
#    Discharge Rate (C)
# 0                 0.5
# 1                 0.5
# 2                 0.5
# ...

# %%
df.tail(5)
# Out:
#                                               Cell ID     Anode Cathode  \
# 132  UL-PUR_R20-EX2_18650_NCA_23C_2.5-96.5_0.5-0.5C_b  graphite     NCA
# 133  UL-PUR_R20-NA7_18650_NCA_23C_2.5-96.5_0.5-0.5C_g  graphite     NCA
# 134  UL-PUR_R20-NA8_18650_NCA_23C_2.5-96.5_0.5-0.5C_h  graphite     NCA
# 135  UL-PUR_R20-NA9_18650_NCA_23C_2.5-96.5_0.5-0.5C_i  graphite     NCA
# 136  UL-PUR_R20-OV1_18650_NCA_23C_2.5-96.5_0.5-0.5C_a  graphite     NCA
#
#      Source   Ah Form Factor  Temperature (C)  Max SOC  Min SOC  \
# 132  UL-PUR  3.4       18650               23     96.5      2.5
# 133  UL-PUR  3.4       18650               23     96.5      2.5
# 134  UL-PUR  3.4       18650               23     96.5      2.5
# 135  UL-PUR  3.4       18650               23     96.5      2.5
# 136  UL-PUR  3.4       18650               23     96.5      2.5
#
#      Charge Rate (C)  Discharge Rate (C)
# 132              0.5                 0.5
# 133              0.5                 0.5
# ...

# %%
df.dtypes
# Out:
# Cell ID                object
# Anode                  object
# Cathode                object
# Source                 object
# Ah                    float64
# Form Factor            object
# Temperature (C)         int64
# Max SOC               float64
# Min SOC               float64
# Charge Rate (C)       float64
# Discharge Rate (C)    float64
# dtype: object

# %%
#df['Cell ID'] = df['Cell ID'].replace('/', '-', regex = True)
# df.to_csv("li-ion_batteries.csv")

# %%
#df = df.drop(['Unnamed: 0.3', 'Unnamed: 0.2', 'Unnamed: 0.1', 'Unnamed: 0'], axis=1)
#df.to_csv("li-ion_batteries.csv")

# %%
df = df.drop('Unnamed: 0', axis=1)
df.to_csv("li-ion_batteries.csv", index = False)

# %%
df.describe().T
# Out:
#                           count          mean           std        min  \
# Cycle_Index              2016.0  1.008500e+03  5.821134e+02      1.000
# Start_Time                  0.0           NaN           NaN        NaN
# End_Time                    0.0           NaN           NaN        NaN
# Test_Time (s)            2016.0  1.649939e+07  9.229917e+06  10907.674
# Min_Current (A)          2016.0 -6.031895e-01  7.258767e-02     -0.675
# Max_Current (A)          2016.0  1.227115e+00  1.230012e-01      0.000
# Min_Voltage (V)          2016.0  2.703217e+00  4.608502e-02      2.699
# Max_Voltage (V)          2016.0  4.199373e+00  2.245615e-02      3.221
# Charge_Capacity (Ah)     2016.0  1.061041e+00  1.529236e-01      0.000
# Discharge_Capacity (Ah)  2016.0  1.069140e+00  2.955629e-01      0.000
# Charge_Energy (Wh)       2016.0  4.264741e+00  6.001928e-01      0.000
# Discharge_Energy (Wh)    2016.0  3.931576e+00  1.193093e+00      0.000
#
# ...

# %%
df.shape
# Out:
# (137, 12)

# %%
#df.StratificationCategoryId1.unique()

# %%
#df..value_counts()
